# %% [markdown]
# ## File IO

# %%
import pymysql     ### mysql-connector-python is used later but this should work the same
                   ### see comparison: https://dev.to/miyachin/there-are-many-options-for-connecting-mysql-from-python-but-lets-use-pymysql-or-mysql-connector-python-for-now-epe
import pandas as pd

# %%
# pandas can read a many data types
# pd.read

# %%
### read csv
pd.read_csv('ComputerSales.csv')
# Out:
#     Sale ID          Contact Sex  Age State Product ID Product Type  \
# 0         1      Paul Thomas   M   43    OH  M01-F0024      Desktop
# 1         2      Margo Simms   F   37    WV  GT13-0024      Desktop
# 2         3        Sam Stine   M   26    PA      I3670      Desktop
# 3         4       Moe Eggert   M   35    PA      I3593       Laptop
# 4         5      Jessica Elk   F   55    PA     15M-ED       Laptop
# 5         6  Sally Struthers   F   45    PA  GT13-0024      Desktop
# 6         7   Michelle Samms   F   46    OH    GA401IV       Laptop
# 7         8     Mick Roberts   M   23    OH    MY2J2LL       Tablet
# 8         9      Ed Klondike   M   52    OH     81TC00       Laptop
# 9        10       Phil Jones   M   56    WV  M01-F0024      Desktop
# 10       11       Rick James   M   49    PA    GA401IV       Laptop
# 11       12         Sue Etna   F   54    OH  GT13-0024      Desktop
# 12       13       Jason Case   M   57    PA     81TC00       Laptop
# ...

# %%
### copy csv
df_csv = pd.read_csv('ComputerSales.csv')
df_csv.to_csv('ComputerSalesBACKUP.csv')

# %%
### excel file ### require openpyexl: pip install openpyexl
pd.read_excel('Financial_Sample.xlsx')
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
### turn csv to excel
df_csv.to_excel('ComputerSales.xlsx')
pd.read_excel('ComputerSales.xlsx')
# Out:
#     Unnamed: 0  Sale ID          Contact Sex  Age State Product ID  \
# 0            0        1      Paul Thomas   M   43    OH  M01-F0024
# 1            1        2      Margo Simms   F   37    WV  GT13-0024
# 2            2        3        Sam Stine   M   26    PA      I3670
# 3            3        4       Moe Eggert   M   35    PA      I3593
# 4            4        5      Jessica Elk   F   55    PA     15M-ED
# 5            5        6  Sally Struthers   F   45    PA  GT13-0024
# 6            6        7   Michelle Samms   F   46    OH    GA401IV
# 7            7        8     Mick Roberts   M   23    OH    MY2J2LL
# 8            8        9      Ed Klondike   M   52    OH     81TC00
# 9            9       10       Phil Jones   M   56    WV  M01-F0024
# 10          10       11       Rick James   M   49    PA    GA401IV
# 11          11       12         Sue Etna   F   54    OH  GT13-0024
# 12          12       13       Jason Case   M   57    PA     81TC00
# ...

# %%
### did "ipython kernel install --user --name=venv" as suggested by 
### https://www.geeksforgeeks.org/using-jupyter-notebook-in-virtual-environment/#
### then pip install connector and ssh tunnel

import mysql.connector
import sshtunnel

ssh_host = "74.208.29.196"
ssh_port = 22
ssh_username = "chen_user"
ssh_password = "passwd2024"

localhost = '127.0.0.1'

database_name = "employees"
database_username = 'chen_user'
database_password = 'passwd2024'


### try except should be used as well but sshtunnel is good to introduce. 
### otherwise just skip the tunnel part and make the dbconn. 
with sshtunnel.SSHTunnelForwarder(
    (ssh_host, 22),
    ssh_username=ssh_username,
    ssh_password=ssh_password,
    remote_bind_address=('127.0.0.1', 3306)

) as tunnel:
    print("test")
    tunnel.start()
    dbconn = mysql.connector.connect(
        host='127.0.0.1',
        user='chen_user',
        password='passwd2024',
        database=database_name,
        # port = 3306,
        use_pure = True,   ### this can be important: use python interface rather than C implementation
        port=tunnel.local_bind_port
    )
    # cursor = dbconn.cursor()
    cursor = dbconn.cursor(buffered=True)  ### https://stackoverflow.com/questions/29772337/python-mysql-connector-unread-result-found-when-using-fetchone
    cursor.execute("SELECT * FROM departments")
    # for row in cursor:
    #     print(row)


    # pd.read_sql('SELECT * FROM departments', con=dbconn) need to save as variable and print
    customer_df = pd.read_sql('SELECT * FROM departments', con=dbconn)
    print(customer_df)



#### 
pd.read_csv('ComputerSales.csv', usecols=['State']).squeeze()   ### squeeze(): make series
# Out:
# test
#   dept_no           dept_name
# 0    d009    Customer Service
# 1    d005         Development
# 2    d002             Finance
# 3    d003     Human Resources
# 4    d001           Marketing
# 5    d004          Production
# 6    d006  Quality Management
# 7    d008            Research
# 8    d007               Sales
# 0     OH
# 1     WV
# 2     PA
# 3     PA
# 4     PA
# 5     PA
# 6     OH
# 7     OH
# 8     OH
# 9     WV
# 10    PA
# 11    OH
# 12    PA
# 13    PA
# 14    OH
# 15    PA
# 16    OH
# 17    NY
# 18    PA
# 19    NY
# 20    PA
# 21    PA
# 22    OH
# 23    WV
# 24    NY
# 25    PA
# 26    OH
# 27    PA
# 28    PA
# 29    WV
# 30    PA
# 31    OH
# 32    PA
# 33    OH
# 34    NY
# 35    NY
# 36    PA
# 37    PA
# 38    PA
# Name: State, dtype: object
